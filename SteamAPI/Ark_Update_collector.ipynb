# %%
# Import necessary libraries
import os
import requests
import pandas as pd
from dotenv import load_dotenv
from datetime import datetime

# Load environment variables from a .env file
load_dotenv()
# Out:
# True

# %%
# Get the Steam API key from the environment variable
api_key = os.getenv('STEAM_API_KEY')
# Set the base URL for the Steam News API
base_url = "https://api.steampowered.com/ISteamNews/GetNewsForApp/v2/"

# %%
# Function to fetch news titles for a given app ID
def fetch_news_titles_for_app(appid, count=100, maxlength=300):
    # Set the parameters for the API request
    params = {
        'appid': appid,
        'count': count,
        'maxlength': maxlength,
        'format': 'json'
    }
    # Make a GET request to the API
    response = requests.get(base_url, params=params)
    # Check if the request was successful
    if response.status_code != 200:
        print(f"Failed to retrieve news for app ID {appid}. Status code: {response.status_code}")
        return []
    # Parse the JSON response
    news_data = response.json()
    # Return the list of news items
    return news_data['appnews']['newsitems']

# %%
# Define the app ID for Ark
ark_appid = 346110

# %%
# Fetch news titles for The Isle
print(f"Fetching news titles for Ark: Survival Evolved...")
news_items = fetch_news_titles_for_app(ark_appid, count=600)  # Increase count to get more data
print(f"Fetched {len(news_items)} news titles for Ark: Survival Evolved.")

# Categorize news items into Updates, Patches, and DevBlogs
updates = [item for item in news_items if 'Update' in item['title']]
patches = [item for item in news_items if 'Patch' in item['title']]
devblogs = [item for item in news_items if 'DevBlog' in item['title']]

print(f"Filtered down to {len(updates)} updates, {len(patches)} patches, and {len(devblogs)} devblogs.")
# Out:
# Fetching news titles for Ark: Survival Evolved...
# Fetched 600 news titles for Ark: Survival Evolved.
# Filtered down to 42 updates, 24 patches, and 0 devblogs.

# %%
# Function to display news titles and dates for each category
def display_news_items(items, category):
    """
    This function prints the titles and dates of news items for a given category.
    
    Parameters:
    - items (list): A list of news items.
    - category (str): The category of the news items (e.g., 'Updates', 'Patches', 'DevBlogs').
    """
    print(f"\n{category}:")  # Print the category name
    for idx, item in enumerate(items):
        title = item['title']  # Get the title of the news item
        date = datetime.utcfromtimestamp(item['date']).strftime('%Y-%m-%d %H:%M:%S')  # Convert the timestamp to a readable date
        # Print the index, title, and date of the news item
        print(f"{idx + 1}. Title: {title}\n   Date: {date}\n")

# Display news items for each category: Updates, Patches, and DevBlogs
display_news_items(updates, "Updates")
display_news_items(patches, "Patches")
display_news_items(devblogs, "DevBlogs")
# Out:
# Updates:
# 1. Title: Community Crunch 380: Community Creature Winner, LiveOps Update, and More!
#    Date: 2023-09-23 00:04:52
#
# 2. Title: Community Crunch 368: ASA Roadmap Update, ASA Comparison, and More!
#    Date: 2023-07-01 00:01:48
#
# 3. Title: Community Crunch 356: ARK Roadmap Update, Rhyniognatha Concept, and More!
#    Date: 2023-04-08 00:09:13
#
# 4. Title: Community Crunch 343: TSOTF Updates, Winter Wonderland Extension, and More!
#    Date: 2023-01-07 01:02:37
#
# 5. Title: Community Crunch 325: Conquest Map Updates, Community Corner, and More!
#    Date: 2017-08-30 01:46:02
#
# 33. Title: Ragnarok Update!
#    Date: 2017-08-16 17:37:35
#
# 34. Title: Ragnarok Update!
#    Date: 2017-08-16 17:37:35
#
# 35. Title: Introducing the Otter, ARK Digest 47, and Sponsored Mod Update!
#    Date: 2017-08-05 07:15:00
#
# 36. Title: Introducing the Otter, ARK Digest 47, and Sponsored Mod Update!
#    Date: 2017-08-05 07:15:00
#
# 37. Title: Ark: Survival Evolved's next patch will feature a 'total inventory menu redesign' (Updated)
#    Date: 2017-03-28 01:55:23
#
# 38. Title: Modder replaces Ark's dinosaurs with Pok mon, is quickly slapped with DMCA notice [Updated]
#    Date: 2017-01-15 20:00:00
#
# 39. Title: Ark Update: Archaeopteryx Gliders, More Optimisations
#    Date: 2016-09-13 11:34:32
#
# 40. Title: Titanosaurus Wreck: Ark Update Adds Dino & New Biome
#    Date: 2016-06-25 13:00:44
#
# 41. Title: SotF: Summer Cup, Survivors League, ARK @ E3, Biome Update, ARK Digest 33, and Community Crunch 52!
#    Date: 2016-06-18 08:38:15
#
# 42. Title: SotF: Summer Cup, Survivors League, ARK @ E3, Biome Update, ARK Digest 33, and Community Crunch 52!
#    Date: 2016-06-18 08:38:15
#
#
# Patches:
# 1. Title: Classic PvP Changes, Patch Wednesday, Social Roundup, and Game Suggestions!
#    Date: 2019-04-22 23:30:58
#
# 2. Title: Extinction Chronicles IV Patch & New Extinction Teasers!
#    Date: 2018-09-18 18:22:59
#
# 3. Title: Patch v278: TLC Pass 1 & 2 Preview, Legacy Migration, Valentines & More
#    Date: 2018-02-10 21:15:17
#
# 4. Title: Patch v278: TLC Pass 1 & 2 Preview, Legacy Migration, Valentines & More
#    Date: 2018-02-10 21:15:17
#
# 5. Title: Dino TLC, Upcoming Patch Notes, Community Crunch 116, & More!
#    Date: 2018-01-27 03:38:44
#
# 6. Title: Dino TLC, Upcoming Patch Notes, Community Crunch 116, & More!
#    Date: 2018-01-27 03:38:44
#
# 7. Title: Patch 258: Hyaenodon, Megatherium, Megalania, Hesperornis, Yutyrannus, and More!
#    Date: 2017-05-29 21:04:43
#
# 8. Title: Patch 258: Hyaenodon, Megatherium, Megalania, Hesperornis, Yutyrannus, and More!
#    Date: 2017-05-29 21:04:43
#
# 9. Title: Patch 257: Giant Bee, Daeodon, Liopleurodon, Kentrosaurus, Tek Cave & Ascension!
#    Date: 2017-05-05 17:34:28
#
# 10. Title: Patch 257: Giant Bee, Daeodon, Liopleurodon, Kentrosaurus, Tek Cave & Ascension!
#    Date: 2017-05-05 17:34:28
#
# 11. Title: Patch 256: Equus, Leedsichthys, Ichthyornis, Iguanodon, Underwater Bases, & More!
#    Date: 2017-03-31 20:38:35
#
# 12. Title: Patch 256: Equus, Leedsichthys, Ichthyornis, Iguanodon, Underwater Bases, & More!
#    Date: 2017-03-31 20:38:35
#
# 13. Title: Patch 255: Electrophorus, Microraptor, Ammonite, Thylacoleo, & Tek Structures!
#    Date: 2017-02-26 09:13:12
#
# 14. Title: Patch 255: Electrophorus, Microraptor, Ammonite, Thylacoleo, & Tek Structures!
#    Date: 2017-02-26 09:13:12
#
# 15. Title: ARK Sale & Patch 254: TEK Tier, Purlovia, Baryonyx, Basilosaurus, Ovis, Hair, and more!
#    Date: 2017-01-30 18:03:24
#
# 16. Title: ARK Sale & Patch 254: TEK Tier, Purlovia, Baryonyx, Basilosaurus, Ovis, Hair, and more!
#    Date: 2017-01-30 18:03:24
#
# 17. Title: Patch 253: Cnidaria, Pegomastax, Therizinosaurus, Troodon, Tusoteuthis, Underwater Caves, & Winter Wonderland 2!
#    Date: 2016-12-23 19:14:52
#
# 18. Title: Patch 253: Cnidaria, Pegomastax, Therizinosaurus, Troodon, Tusoteuthis, Underwater Caves, & Winter Wonderland 2!
#    Date: 2016-12-23 19:14:52
#
# 19. Title: Patch 252: Achatina, Megalosaurus, Moschops, Pachyrhinosaurus, New Caves and more!
#    Date: 2016-11-24 05:13:33
#
# 20. Title: Patch 252: Achatina, Megalosaurus, Moschops, Pachyrhinosaurus, New Caves and more!
#    Date: 2016-11-24 05:13:33
#
# 21. Title: Patch 248: Procedurally Generated Maps, Kaprosuchus, Diplocaulus, Chalicotherium, and more!
#    Date: 2016-10-21 00:29:51
#
# 22. Title: Patch 248: Procedurally Generated Maps, Kaprosuchus, Diplocaulus, Chalicotherium, and more!
#    Date: 2016-10-21 00:29:51
#
# 23. Title: Patch 247: Archaeopteryx, Tapejara, and more!
#    Date: 2016-09-12 19:43:09
#
# 24. Title: Patch 247: Archaeopteryx, Tapejara, and more!
#    Date: 2016-09-12 19:43:09
#
#
# DevBlogs:

# %%
# Function to convert news items to DataFrame
def news_items_to_dataframe(news_items, category):
    """
    This function converts a list of news items to a DataFrame with an additional category column.
    
    Parameters:
    - news_items (list): A list of news items.
    - category (str): The category of the news items (e.g., 'Update', 'Patch', 'DevBlog').
    
    Returns:
    - pd.DataFrame: A DataFrame containing the news items with title, date, and category.
    """
    data = {
        'Title': [item['title'] for item in news_items],
        'Date': [datetime.utcfromtimestamp(item['date']).strftime('%Y-%m-%d %H:%M:%S') for item in news_items],
        'Category': [category] * len(news_items)  # Add a category column
    }
    return pd.DataFrame(data)

# Convert updates, patches, and devblogs to DataFrames
updates_df = news_items_to_dataframe(updates, 'Update')
patches_df = news_items_to_dataframe(patches, 'Patch')
devblogs_df = news_items_to_dataframe(devblogs, 'DevBlog')

# Concatenate all DataFrames into one
all_news_df = pd.concat([updates_df, patches_df, devblogs_df])

# Save the combined DataFrame to a single CSV file
all_news_df.to_csv('ark_update_data.csv', index=False)

print("Data saved to 'ark_update_data.csv'")
# Out:
# Data saved to 'the_isle_update_data.csv'
